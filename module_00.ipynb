# %% [markdown]
# # Set up environment

# %%
# Create python virtual environment for project. Must be in project folder
python3 -m venv venv
source venv/bin/activate

# %%
# Install required packages
pip install numpy pandas scikit-learn matplotlib seaborn biopython jupyter ipykernel

# %% [markdown]
# ### Make sure VS code is pointed to the correct virtual environment
#
# Press Cmd+Shift+P to open the command palette
# Type "Python: Select Interpreter" and select it
# Choose the option that shows `./venv/bin/python` or `Python 3.x.x ('venv')`
